# %% [markdown]
# <a href="https://colab.research.google.com/github/sri-prasanna-pendyala/ai-mentor-portfolio/blob/main/Day1_Setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q google-genai

# %%
import os, getpass

os.environ['GEMINI_API_KEY'] = getpass.getpass(
    'Paste your Google AI Studio key: '
)
# Out:
# Paste your Google AI Studio key: ··········

# %%
from google import genai

client = genai.Client(
    api_key=os.environ['GEMINI_API_KEY']
)

resp = client.models.generate_content(
    model='gemini-2.5-flash',
    contents='Explain the 5-Layer AI Skill Pyramid in 4 short bullet points.'
)

print(resp.text)
# Out:
# The 5-Layer AI Skill Pyramid outlines the hierarchical progression of skills needed for AI development:
#
# *   **Foundational Skills:** The base layer, comprising core abilities like mathematics (linear algebra, calculus), statistics, programming (Python), data structures, and algorithms.
# *   **Data Engineering & ML Engineering:** Progresses to skills in data collection, cleaning, storage, and processing (Data Engineering), followed by developing, training, and evaluating classic machine learning models (ML Engineering).
# *   **AI/Deep Learning Engineering:** Focuses on advanced AI techniques, including deep learning frameworks, neural network architectures, and specialized AI models (e.g., NLP, computer vision).
# *   **AI Product/Solution:** The pinnacle, involving deploying, managing (MLOps), scaling, integrating, and ensuring the ethical application of AI models to create real-world products and deliver business value.
